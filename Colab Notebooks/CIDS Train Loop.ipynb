# %% [markdown]
# # CIDS: Conventional Intrusion Detection System
#
#
# ---
#
#
# This notebook contains code for training multiple conventional (non-federated) autoencoder-based anomaly detectors for the SynCAN dataset.

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from psutil import virtual_memory
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(f'GPU: {gpu_info[599:619]}')
ram_gb = virtual_memory().total / 1e9
print(f'RAM: {ram_gb:.1f} GB')
# Out:
# GPU: NVIDIA A100-SXM...
# RAM: 89.6 GB

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import layers
import matplotlib.pyplot as plt

# %%
signal_counts = [2, 3, 2, 1, 2, 2, 2, 1, 1, 4] # number of signals contained in each message ID

# %%
START_ID = 1
END_ID = 10

TRAIN_SPLIT = 0.8
VAL_SPLIT = 0.1
TIME_STEPS = 100
SEQ_STRIDE = TIME_STEPS // 2
EPOCHS = 2
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DROP_OUT = True
LOSS_FUNCTION = 'mse'
METRIC = 'mean_absolute_percentage_error'
PATIENCE = 1
DIRECTORY = "/content/drive/MyDrive/Colab Notebooks/models/cids/"

# %%
# Download SynCAN dataset from the ETAS github
# !git clone https://github.com/etas/SynCAN.git &> /dev/null
# !unzip ./SynCAN/\*.zip -d ./SynCAN/. &> /dev/null
# !rm ./SynCAN/*.zip &> /dev/null

# %%
def train_csv2df(dir_path): # imports training files into a dataframe
    data_frames = []
    csv_path = dir_path + '/train_1.csv'    # train 1 contains header
    df_temp = pd.read_csv(csv_path)
    data_frames.append(df_temp)
    for i in range(2, 5):
        csv_path = dir_path + '/train_' + str(i) + '.csv'
        df_temp = pd.read_csv(csv_path, header=None, names=['Label',  'Time', 'ID',
                                                            'Signal1', 'Signal2',  'Signal3', 'Signal4'])
        data_frames.append(df_temp)
    df = pd.concat(data_frames)
    return df

def prepare_train_df(): # convert csv, isolate message ID and remove unused columns
    df = train_csv2df('/content/SynCAN')
    print(f'{len(df):,} total messages (id1,id2,...,id10)')

    df = df[:][df.ID==MSG_ID] # use only messages with MSG_ID
    df = df.dropna(axis=1, how='all') # remove unused signal columns
    df.reset_index(drop=True, inplace=True)

    df_labels = df.iloc[:,0:1].astype(int) # dataframe of labels (removing Time and ID columns)
    df = df.iloc[:,3:] # dataframe of signal values
    df = df_labels.join(df)
    print(f'{len(df):,} messages used ({MSG_ID})\n')
    return df

def timeseries_dataset(
    data,
    targets,
    sequence_length,
    data_is_target=False,
    sequence_stride=1,
    sampling_rate=1,
    batch_size=1,
    shuffle=False,
    seed=None,
    start_index=None,
    end_index=None):
  
  if start_index is None:
    start_index = 0
  if end_index is None:
    end_index = len(data)

  # Determine the lowest dtype to store start positions (to lower memory usage).
  num_seqs = end_index - start_index - (sequence_length * sampling_rate) + 1
  if targets is not None:
    num_seqs = min(num_seqs, len(targets))
  if num_seqs < 2147483647:
    index_dtype = 'int32'
  else:
    index_dtype = 'int64'

  # Generate start positions
  start_positions = np.arange(0, num_seqs, sequence_stride, dtype=index_dtype)
  if shuffle:
    if seed is None:
      seed = np.random.randint(1e6)
    rng = np.random.RandomState(seed)
    rng.shuffle(start_positions)

  sequence_length = tf.cast(sequence_length, dtype=index_dtype)
  sampling_rate = tf.cast(sampling_rate, dtype=index_dtype)

  positions_ds = tf.data.Dataset.from_tensors(start_positions).repeat()

  # For each initial window position, generates indices of the window elements
  indices = tf.data.Dataset.zip(
      (tf.data.Dataset.range(len(start_positions)), positions_ds)).map(
          lambda i, positions: tf.range(  # pylint: disable=g-long-lambda
              positions[i],
              positions[i] + sequence_length * sampling_rate,
              sampling_rate),
          num_parallel_calls=tf.data.AUTOTUNE)

  dataset = sequences_from_indices(data, indices, start_index, end_index)
  if targets is not None:
    indices = tf.data.Dataset.zip(
        (tf.data.Dataset.range(len(start_positions)), positions_ds)).map(
            lambda i, positions: positions[i],
            num_parallel_calls=tf.data.AUTOTUNE)
    target_ds = sequences_from_indices(
        targets, indices, start_index, end_index)
    dataset = tf.data.Dataset.zip((dataset, target_ds))
  else:
    if data_is_target:
        dataset = tf.data.Dataset.zip((dataset, dataset))
  dataset = dataset.prefetch(tf.data.AUTOTUNE)
  if batch_size is not None:
    if shuffle:
      # Shuffle locally at each iteration
      dataset = dataset.shuffle(buffer_size=batch_size * 8, seed=seed)
    dataset = dataset.batch(batch_size)
  else:
    if shuffle:
      dataset = dataset.shuffle(buffer_size=1024, seed=seed)
  return dataset

def sequences_from_indices(array, indices_ds, start_index, end_index):
  dataset = tf.data.Dataset.from_tensors(array[start_index : end_index])
  dataset = tf.data.Dataset.zip((dataset.repeat(), indices_ds)).map(
      lambda steps, inds: tf.gather(steps, inds),  # pylint: disable=unnecessary-lambda
      num_parallel_calls=tf.data.AUTOTUNE)
  return dataset

def SynCAN_train_ds(df):
    values = df.to_numpy()[:,1:]
    ds = timeseries_dataset(
        values,
        None,
        data_is_target = True,
        sequence_length = TIME_STEPS,
        sequence_stride = SEQ_STRIDE,
        # batch_size = BATCH_SIZE
    )
    return ds

def get_CIDS_model(time_steps, input_dim, latent_dim, drop_out=False):
    inputs = layers.Input(shape=(time_steps, input_dim)) # shape = (time_steps, data_dimension/num_features)
    # encoder
    x = layers.Dense(latent_dim*2, activation='tanh')(inputs)
    if drop_out: x = layers.Dropout(0.2)(x)
    enc_out, enc_hidden = layers.GRU(latent_dim, return_sequences=True, return_state=True, activation="tanh")(x)
    if drop_out:
        enc_out = layers.Dropout(0.2)(enc_out)
        enc_hidden = layers.Dropout(0.2)(enc_hidden)
    # decoder
    dec_out , dec_hidden = layers.GRU(latent_dim, return_sequences=True, return_state=True, activation="tanh")(enc_out)
    if drop_out:
        dec_out = layers.Dropout(0.2)(dec_out)
        dec_hidden = layers.Dropout(0.2)(dec_hidden)
    
    outputs = layers.Dense(input_dim, activation='tanh')(dec_out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %% [markdown]
# # Model Training Loop

# %%
for ID in range(START_ID, END_ID+1):
    MSG_ID = 'id'+str(ID)      # each message contains 1-4 signals that are associated with the specified message ID
    NUM_SIGNALS = signal_counts[ID-1]
    LATENT_DIM = 32 * NUM_SIGNALS
    FILEPATH = DIRECTORY+MSG_ID+"_model_"+str(TIME_STEPS)+".h5"
    df = prepare_train_df()
    data_length = len(df)
    train_size = (int(data_length*TRAIN_SPLIT) // SEQ_STRIDE) * SEQ_STRIDE
    val_size = (int(data_length*VAL_SPLIT) // SEQ_STRIDE) * SEQ_STRIDE
    test_size = ((data_length - train_size - val_size) // SEQ_STRIDE) * SEQ_STRIDE

    train_df = df.iloc[:train_size]
    val_df = df[train_size:train_size+val_size]
    test_df = df.iloc[-test_size:]

    train_ds = SynCAN_train_ds(train_df)
    val_ds = SynCAN_train_ds(val_df)
    test_ds = SynCAN_train_ds(test_df)

    datasets = {'train': train_ds, 'val': val_ds, 'test': test_ds}
    for key, item in datasets.items():
        print(f"{key.upper()}: \t{item.__len__().numpy():,} subsequences of length {TIME_STEPS}")

    callbacks_list = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=PATIENCE,
        ),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=FILEPATH,
            monitor="val_loss",
            save_best_only=True,
        )
    ]

    model = get_CIDS_model(TIME_STEPS, input_dim=NUM_SIGNALS, latent_dim=LATENT_DIM, drop_out=DROP_OUT)

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=LOSS_FUNCTION,
        metrics=[METRIC])
    model.summary()

    history = model.fit(train_ds,
                        epochs=EPOCHS,
                        validation_data=val_ds,
                        use_multiprocessing=True,
                        workers=6,
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        callbacks=callbacks_list)

    loss, metric = model.evaluate(val_ds, verbose=0)
    print(f'Validation loss: {loss:.5}\nValidation {METRIC}: {metric:.5}')
    print()

    loss, metric = model.evaluate(test_ds, verbose=0)
    print(f'Test loss: {loss:.5}\nTest {METRIC}: {metric:.5}')        # current best: 0.000229148383368738
# Out:
# 29,669,726 total messages (id1,id2,...,id10)
# 4,139,819 messages used (id1)
#
# TRAIN: 	66,236 subsequences of length 100
# VAL: 	8,278 subsequences of length 100
# TEST: 	8,279 subsequences of length 100
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 2)]          0
#
#  dense (Dense)               (None, 100, 128)          384
#
#  dropout (Dropout)           (None, 100, 128)          0
#
#  gru (GRU)                   [(None, 100, 64),         37248
#                               (None, 64)]
#
#  dropout_1 (Dropout)         (None, 100, 64)           0
#
#  gru_1 (GRU)                 [(None, 100, 64),         24960
#                               (None, 64)]
#
#  dropout_3 (Dropout)         (None, 100, 64)           0
#
#  dense_1 (Dense)             (None, 100, 2)            130
#
# =================================================================
# Total params: 62,722
# Trainable params: 62,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 66236/66236 [==============================] - 640s 10ms/step - loss: 6.6401e-04 - mean_absolute_percentage_error: 2310189.2500 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 3160569.7500
# Epoch 2/2
# 66236/66236 [==============================] - 629s 9ms/step - loss: 7.1022e-04 - mean_absolute_percentage_error: 2355051.2500 - val_loss: 0.0168 - val_mean_absolute_percentage_error: 2679882.7500
# Validation loss: 0.016847
# Validation mean_absolute_percentage_error: 2.6799e+06
#
# Test loss: 0.10701
# Test mean_absolute_percentage_error: 1.8802e+07
# 29,669,726 total messages (id1,id2,...,id10)
# 2,070,144 messages used (id2)
#
# TRAIN: 	33,121 subsequences of length 100
# VAL: 	4,139 subsequences of length 100
# TEST: 	4,139 subsequences of length 100
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 3)]          0
#
#  dense_2 (Dense)             (None, 100, 192)          768
#
#  dropout_5 (Dropout)         (None, 100, 192)          0
#
#  gru_2 (GRU)                 [(None, 100, 96),         83520
#                               (None, 96)]
#
#  dropout_6 (Dropout)         (None, 100, 96)           0
#
#  gru_3 (GRU)                 [(None, 100, 96),         55872
#                               (None, 96)]
#
#  dropout_8 (Dropout)         (None, 100, 96)           0
#
#  dense_3 (Dense)             (None, 100, 3)            291
#
# =================================================================
# Total params: 140,451
# Trainable params: 140,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 33121/33121 [==============================] - 322s 10ms/step - loss: 7.9159e-04 - mean_absolute_percentage_error: 3246265.7500 - val_loss: 0.0088 - val_mean_absolute_percentage_error: 5348550.0000
# Epoch 2/2
# 33121/33121 [==============================] - 320s 10ms/step - loss: 5.7710e-04 - mean_absolute_percentage_error: 2558614.0000 - val_loss: 0.0116 - val_mean_absolute_percentage_error: 12749490.0000
# Validation loss: 0.011595
# Validation mean_absolute_percentage_error: 1.2749e+07
#
# Test loss: 0.015127
# Test mean_absolute_percentage_error: 1.1171e+07
# 29,669,726 total messages (id1,id2,...,id10)
# 4,139,826 messages used (id3)
#
# TRAIN: 	66,236 subsequences of length 100
# VAL: 	8,278 subsequences of length 100
# TEST: 	8,279 subsequences of length 100
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100, 2)]          0
#
#  dense_4 (Dense)             (None, 100, 128)          384
#
#  dropout_10 (Dropout)        (None, 100, 128)          0
#
#  gru_4 (GRU)                 [(None, 100, 64),         37248
#                               (None, 64)]
#
#  dropout_11 (Dropout)        (None, 100, 64)           0
#
#  gru_5 (GRU)                 [(None, 100, 64),         24960
#                               (None, 64)]
#
#  dropout_13 (Dropout)        (None, 100, 64)           0
#
#  dense_5 (Dense)             (None, 100, 2)            130
#
# =================================================================
# Total params: 62,722
# Trainable params: 62,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 66236/66236 [==============================] - 635s 10ms/step - loss: 7.4388e-04 - mean_absolute_percentage_error: 2109900.7500 - val_loss: 8.3826e-05 - val_mean_absolute_percentage_error: 1739853.3750
# Epoch 2/2
# 66236/66236 [==============================] - 630s 10ms/step - loss: 2.3257e-04 - mean_absolute_percentage_error: 1644101.1250 - val_loss: 2.3550e-05 - val_mean_absolute_percentage_error: 507395.3750
# Validation loss: 2.355e-05
# Validation mean_absolute_percentage_error: 5.074e+05
#
# Test loss: 2.2259e-05
# Test mean_absolute_percentage_error: 5.1157e+05
# 29,669,726 total messages (id1,id2,...,id10)
# 1,380,097 messages used (id4)
#
# TRAIN: 	22,080 subsequences of length 100
# VAL: 	2,759 subsequences of length 100
# TEST: 	2,759 subsequences of length 100
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 100, 1)]          0
#
#  dense_6 (Dense)             (None, 100, 64)           128
#
#  dropout_15 (Dropout)        (None, 100, 64)           0
#
#  gru_6 (GRU)                 [(None, 100, 32),         9408
#                               (None, 32)]
#
#  dropout_16 (Dropout)        (None, 100, 32)           0
#
#  gru_7 (GRU)                 [(None, 100, 32),         6336
#                               (None, 32)]
#
#  dropout_18 (Dropout)        (None, 100, 32)           0
#
#  dense_7 (Dense)             (None, 100, 1)            33
#
# =================================================================
# Total params: 15,905
# Trainable params: 15,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 22080/22080 [==============================] - 213s 10ms/step - loss: 1.7681e-04 - mean_absolute_percentage_error: 2939128.2500 - val_loss: 3.7633e-05 - val_mean_absolute_percentage_error: 837321.6875
# Epoch 2/2
# 22080/22080 [==============================] - 210s 10ms/step - loss: 1.3413e-04 - mean_absolute_percentage_error: 2659165.2500 - val_loss: 1.4867e-05 - val_mean_absolute_percentage_error: 576799.3750
# Validation loss: 1.4867e-05
# Validation mean_absolute_percentage_error: 5.768e+05
#
# Test loss: 1.0534e-05
# Test mean_absolute_percentage_error: 5.8809e+05
# 29,669,726 total messages (id1,id2,...,id10)
# 4,139,820 messages used (id5)
#
# TRAIN: 	66,236 subsequences of length 100
# VAL: 	8,278 subsequences of length 100
# TEST: 	8,279 subsequences of length 100
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100, 2)]          0
#
#  dense_8 (Dense)             (None, 100, 128)          384
#
#  dropout_20 (Dropout)        (None, 100, 128)          0
#
#  gru_8 (GRU)                 [(None, 100, 64),         37248
#                               (None, 64)]
#
#  dropout_21 (Dropout)        (None, 100, 64)           0
#
#  gru_9 (GRU)                 [(None, 100, 64),         24960
#                               (None, 64)]
#
#  dropout_23 (Dropout)        (None, 100, 64)           0
#
#  dense_9 (Dense)             (None, 100, 2)            130
#
# =================================================================
# Total params: 62,722
# Trainable params: 62,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 66236/66236 [==============================] - 631s 9ms/step - loss: 8.4136e-04 - mean_absolute_percentage_error: 426696.1250 - val_loss: 4.5438e-04 - val_mean_absolute_percentage_error: 573564.6250
# Epoch 2/2
# 66236/66236 [==============================] - 625s 9ms/step - loss: 3.4315e-04 - mean_absolute_percentage_error: 370240.7188 - val_loss: 2.2249e-04 - val_mean_absolute_percentage_error: 398041.2188
# Validation loss: 0.00022249
# Validation mean_absolute_percentage_error: 3.9804e+05
#
# Test loss: 0.00025016
# Test mean_absolute_percentage_error: 6.6343e+05
# 29,669,726 total messages (id1,id2,...,id10)
# 2,070,144 messages used (id6)
#
# TRAIN: 	33,121 subsequences of length 100
# VAL: 	4,139 subsequences of length 100
# TEST: 	4,139 subsequences of length 100
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 100, 2)]          0
#
#  dense_10 (Dense)            (None, 100, 128)          384
#
#  dropout_25 (Dropout)        (None, 100, 128)          0
#
#  gru_10 (GRU)                [(None, 100, 64),         37248
#                               (None, 64)]
#
#  dropout_26 (Dropout)        (None, 100, 64)           0
#
#  gru_11 (GRU)                [(None, 100, 64),         24960
#                               (None, 64)]
#
#  dropout_28 (Dropout)        (None, 100, 64)           0
#
#  dense_11 (Dense)            (None, 100, 2)            130
#
# =================================================================
# Total params: 62,722
# Trainable params: 62,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 33121/33121 [==============================] - 315s 9ms/step - loss: 0.0015 - mean_absolute_percentage_error: 2292845.7500 - val_loss: 4.9800e-04 - val_mean_absolute_percentage_error: 955486.3750
# Epoch 2/2
# 33121/33121 [==============================] - 312s 9ms/step - loss: 5.0164e-04 - mean_absolute_percentage_error: 1757047.0000 - val_loss: 1.3235e-04 - val_mean_absolute_percentage_error: 946689.8750
# Validation loss: 0.00013235
# Validation mean_absolute_percentage_error: 9.4669e+05
#
# Test loss: 0.0037532
# Test mean_absolute_percentage_error: 3.5215e+06
# 29,669,726 total messages (id1,id2,...,id10)
# 4,139,816 messages used (id7)
#
# TRAIN: 	66,236 subsequences of length 100
# VAL: 	8,278 subsequences of length 100
# TEST: 	8,279 subsequences of length 100
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100, 2)]          0
#
#  dense_12 (Dense)            (None, 100, 128)          384
#
#  dropout_30 (Dropout)        (None, 100, 128)          0
#
#  gru_12 (GRU)                [(None, 100, 64),         37248
#                               (None, 64)]
#
#  dropout_31 (Dropout)        (None, 100, 64)           0
#
#  gru_13 (GRU)                [(None, 100, 64),         24960
#                               (None, 64)]
#
#  dropout_33 (Dropout)        (None, 100, 64)           0
#
#  dense_13 (Dense)            (None, 100, 2)            130
#
# =================================================================
# Total params: 62,722
# Trainable params: 62,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 66236/66236 [==============================] - 622s 9ms/step - loss: 5.3879e-04 - mean_absolute_percentage_error: 2450888.2500 - val_loss: 4.4748e-04 - val_mean_absolute_percentage_error: 2141192.5000
# Epoch 2/2
# 66236/66236 [==============================] - 619s 9ms/step - loss: 2.9147e-04 - mean_absolute_percentage_error: 2085434.8750 - val_loss: 3.6807e-04 - val_mean_absolute_percentage_error: 890474.8125
# Validation loss: 0.00036807
# Validation mean_absolute_percentage_error: 8.9047e+05
#
# Test loss: 0.00039477
# Test mean_absolute_percentage_error: 1.1006e+06
# 29,669,726 total messages (id1,id2,...,id10)
# 4,139,819 messages used (id8)
#
# TRAIN: 	66,236 subsequences of length 100
# VAL: 	8,278 subsequences of length 100
# TEST: 	8,279 subsequences of length 100
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 100, 1)]          0
#
#  dense_14 (Dense)            (None, 100, 64)           128
#
#  dropout_35 (Dropout)        (None, 100, 64)           0
#
#  gru_14 (GRU)                [(None, 100, 32),         9408
#                               (None, 32)]
#
#  dropout_36 (Dropout)        (None, 100, 32)           0
#
#  gru_15 (GRU)                [(None, 100, 32),         6336
#                               (None, 32)]
#
#  dropout_38 (Dropout)        (None, 100, 32)           0
#
#  dense_15 (Dense)            (None, 100, 1)            33
#
# =================================================================
# Total params: 15,905
# Trainable params: 15,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 66236/66236 [==============================] - 624s 9ms/step - loss: 1.6701e-04 - mean_absolute_percentage_error: 822311.4375 - val_loss: 1.7865e-05 - val_mean_absolute_percentage_error: 463454.0000
# Epoch 2/2
# 66236/66236 [==============================] - 618s 9ms/step - loss: 9.2971e-05 - mean_absolute_percentage_error: 739121.8750 - val_loss: 1.9978e-05 - val_mean_absolute_percentage_error: 369657.7188
# Validation loss: 1.9978e-05
# Validation mean_absolute_percentage_error: 3.6966e+05
#
# Test loss: 2.3603e-05
# Test mean_absolute_percentage_error: 5.6427e+05
# 29,669,726 total messages (id1,id2,...,id10)
# 2,070,144 messages used (id9)
#
# TRAIN: 	33,121 subsequences of length 100
# VAL: 	4,139 subsequences of length 100
# TEST: 	4,139 subsequences of length 100
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 100, 1)]          0
#
#  dense_16 (Dense)            (None, 100, 64)           128
#
#  dropout_40 (Dropout)        (None, 100, 64)           0
#
#  gru_16 (GRU)                [(None, 100, 32),         9408
#                               (None, 32)]
#
#  dropout_41 (Dropout)        (None, 100, 32)           0
#
#  gru_17 (GRU)                [(None, 100, 32),         6336
#                               (None, 32)]
#
#  dropout_43 (Dropout)        (None, 100, 32)           0
#
#  dense_17 (Dense)            (None, 100, 1)            33
#
# =================================================================
# Total params: 15,905
# Trainable params: 15,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 33121/33121 [==============================] - 314s 9ms/step - loss: 1.4396e-04 - mean_absolute_percentage_error: 2.1596 - val_loss: 4.7019e-06 - val_mean_absolute_percentage_error: 0.4620
# Epoch 2/2
# 33121/33121 [==============================] - 309s 9ms/step - loss: 5.7810e-05 - mean_absolute_percentage_error: 1.6425 - val_loss: 1.5733e-05 - val_mean_absolute_percentage_error: 0.8512
# Validation loss: 1.5733e-05
# Validation mean_absolute_percentage_error: 0.85122
#
# Test loss: 1.2446e-05
# Test mean_absolute_percentage_error: 0.83533
# 29,669,726 total messages (id1,id2,...,id10)
# 1,380,097 messages used (id10)
#
# TRAIN: 	22,080 subsequences of length 100
# VAL: 	2,759 subsequences of length 100
# TEST: 	2,759 subsequences of length 100
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 100, 4)]          0
#
#  dense_18 (Dense)            (None, 100, 256)          1280
#
#  dropout_45 (Dropout)        (None, 100, 256)          0
#
#  gru_18 (GRU)                [(None, 100, 128),        148224
#                               (None, 128)]
#
#  dropout_46 (Dropout)        (None, 100, 128)          0
#
#  gru_19 (GRU)                [(None, 100, 128),        99072
#                               (None, 128)]
#
#  dropout_48 (Dropout)        (None, 100, 128)          0
#
#  dense_19 (Dense)            (None, 100, 4)            516
#
# =================================================================
# Total params: 249,092
# Trainable params: 249,092
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 22080/22080 [==============================] - 224s 10ms/step - loss: 0.0012 - mean_absolute_percentage_error: 1080619.0000 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 472784.3438
# Epoch 2/2
# 22080/22080 [==============================] - 221s 10ms/step - loss: 4.3442e-04 - mean_absolute_percentage_error: 836821.8750 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 403481.0625
# Validation loss: 0.0010805
# Validation mean_absolute_percentage_error: 4.0348e+05
#
# Test loss: 0.0014015
# Test mean_absolute_percentage_error: 5.7812e+05
